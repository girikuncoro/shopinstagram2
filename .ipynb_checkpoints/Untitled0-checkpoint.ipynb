# %%
import json
from instagram.client import InstagramAPI
from urllib import urlopen
from pprint import pprint

# Get stores data from json file
json_data = open('analyses/bali_stores.json')
stores = json.load(json_data)
json_data.close()

client_id = "ff8b092c952a43b18e6fc41e33da8150"
base_url = "https://api.instagram.com/v1"
endpoints = "users"
url = "{0}/{1}/{2}/media/recent/?client_id={3}".format(base_url, endpoints, "965938803", client_id)

json_data = urlopen(url).read()
response = json.loads(json_data)
print response['data'][0]['likes']['count']
pprint (response['data'][9]['comments']['count'])
pprint (response['data'][9]['created_time'])
pprint(response['pagination']['next_url'])

for store in stores:
    #print stores[store]['uid']
    print store
# Out:
# 30
# 0
# u'1424871072'
# u'https://api.instagram.com/v1/users/965938803/media/recent?max_id=928203274228298725_965938803&client_id=ff8b092c952a43b18e6fc41e33da8150'
# {u'username': u'kathleenroom', u'uid': u'965938803'}
# {u'username': u'makeuptoolshop', u'uid': u'242236159'}
# {u'username': u'mallonlineshop', u'uid': u'1294216289'}
# {u'username': u'trendshion', u'uid': u'323786501'}
# {u'username': u'leo6s', u'uid': u'1546189536'}
# {u'username': u'cuddlepot', u'uid': u'1610068918'}
# {u'username': u'agusbambino', u'uid': u'418214094'}
# {u'username': u'larry_809_', u'uid': u'436321931'}
# {u'username': u'nymphaea_boutique', u'uid': u'455857009'}
# {u'username': u'vagacova_nikka', u'uid': u'1032524861'}
# {u'username': u'simishop', u'uid': u'229793390'}
# {u'username': u'dondonshop', u'uid': u'41973099'}
# {u'username': u'kesiasyamlan', u'uid': u'1245553890'}
# {u'username': u'ampshop_', u'uid': u'145816763'}
# {u'username': u'suwendraiwayan', u'uid': u'939125412'}
# {u'username': u'chocolastore', u'uid': u'551644367'}
# {u'username': u'prastanababyshop', u'uid': u'919693333'}
# {u'username': u'dewii_grosirkosmetik', u'uid': u'681021191'}
# {u'username': u'denatashop', u'uid': u'406174055'}
# {u'username': u'rikyun_corner', u'uid': u'366893420'}
# {u'username': u'twinkl_bee', u'uid': u'664838565'}
# {u'username': u'glorystore1', u'uid': u'402741701'}
# {u'username': u'estellecollection', u'uid': u'375616047'}
# {u'username': u'nikitasc', u'uid': u'203253589'}
# {u'username': u'cleopatracentra', u'uid': u'1332448088'}
# {u'username': u'inacarina_', u'uid': u'571233513'}
# {u'username': u'queen_houseware', u'uid': u'415587956'}
# {u'username': u'thirteen_collections', u'uid': u'531106257'}
# {u'username': u'marundashop', u'uid': u'1481984621'}
# {u'username': u'supplierqweena', u'uid': u'1415511061'}
# {u'username': u'pesanggrahanshop', u'uid': u'1288396214'}
# {u'username': u'mzkaywraps', u'uid': u'557765696'}
# {u'username': u'astinasshop', u'uid': u'261195172'}
# {u'username': u'jendelarumahsby', u'uid': u'331288194'}
# {u'username': u'stroberimintnew', u'uid': u'1273427460'}
# {u'username': u'gulagula_id', u'uid': u'1537563464'}
# {u'username': u'ichaawulandari', u'uid': u'8828318'}
# {u'username': u'purpleliciousshop', u'uid': u'355541089'}
# {u'username': u'brancheeshop', u'uid': u'267491203'}
# {u'username': u'daun.cincau', u'uid': u'1336547282'}
# {u'username': u'tipsbodyideal', u'uid': u'570844098'}
# {u'username': u'fergisshop', u'uid': u'244649414'}
# {u'username': u'valiribunis', u'uid': u'1273153582'}
# {u'username': u'lemarisikecil', u'uid': u'1233153980'}
# {u'username': u'ladiesshopy', u'uid': u'1202229190'}
# {u'username': u'wiga_shop', u'uid': u'418098921'}
# {u'username': u'febrinafebrin', u'uid': u'1072954641'}
# {u'username': u'aikofashion', u'uid': u'1523728230'}
# {u'username': u'bebemart_online', u'uid': u'1364924395'}
# {u'username': u'ropaonline_shop', u'uid': u'498117487'}

# %%
# Fetch next posts batch
def get_next_page(content):
    if 'pagination' in content:
        if 'next_url' in content['pagination']:
            return content['pagination']['next_url']
        else:
            return ''
    else:
        return ''

# MAIN
# Crawl posts from each page
count_caption,count_stores = 0,1
contents = ''
content = ''

json_data = open('analyses/bali_stores_sample.json')
stores = json.load(json_data)
json_data.close()

for store in stores:
    uid = store['uid']
    url = "{0}/{1}/{2}/media/recent/?client_id={3}".format(base_url, endpoints, uid, client_id)
    while url != '':
        next_data = urlopen(url).read()
        response = json.loads(next_data)
        for i in range(0, len(response['data'])):
            if 'data' in response:
                data = response['data'][i]
                #write_to_txt(response['data'][i])
                content += ',{' + '"times":"{0}","likes":{1},"comments":{2}'.format(data['created_time'], data['likes']['count'], data['comments']['count']) + '}'
                count_caption += 1
        url = get_next_page(response)
        if url == '':
            contents += '"{0}":[{1}]'.format(uid, content[1:])
    print 'crawled {0} posts from {1} stores'.format(count_caption, count_stores)
    count_stores += 1
    contents += ','
print '{' + contents[:-1] + '}'
# Out:
# crawled 415 posts from 1 stores
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-be342eea1805> in <module>()
#      23     url = "{0}/{1}/{2}/media/recent/?client_id={3}".format(base_url, endpoints, uid, client_id)
#      24     while url != '':
# ---> 25         next_data = urlopen(url).read()
#      26         response = json.loads(next_data)
#      27         for i in range(0, len(response['data'])):
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/urllib.pyc in urlopen(url, data, proxies)
#      85         opener = _urlopener
#      86     if data is None:
# ---> 87         return opener.open(url)
#      88     else:
#      89         return opener.open(url, data)
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/urllib.pyc in open(self, fullurl, data)
#     206         try:
#     207             if data is None:
# --> 208                 return getattr(self, name)(url)
#     209             else:
#     210                 return getattr(self, name)(url, data)
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/urllib.pyc in open_https(self, url, data)
#     436             for args in self.addheaders: h.putheader(*args)
#     437             h.endheaders(data)
# --> 438             errcode, errmsg, headers = h.getreply()
#     439             fp = h.getfile()
#     440             if errcode == -1:
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/httplib.pyc in getreply(self, buffering)
#    1115         try:
#    1116             if not buffering:
# -> 1117                 response = self._conn.getresponse()
#    1118             else:
#    1119                 #only add this keyword if non-default for compatibility
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/httplib.pyc in getresponse(self, buffering)
#    1043         response = self.response_class(*args, **kwds)
#    1044
# -> 1045         response.begin()
#    1046         assert response.will_close != _UNKNOWN
#    1047         self.__state = _CS_IDLE
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/httplib.pyc in begin(self)
#     407         # read until we get a non-100 response
#     408         while True:
# --> 409             version, status, reason = self._read_status()
#     410             if status != CONTINUE:
#     411                 break
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/httplib.pyc in _read_status(self)
#     363     def _read_status(self):
#     364         # Initialize with Simple-Response defaults
# --> 365         line = self.fp.readline(_MAXLINE + 1)
#     366         if len(line) > _MAXLINE:
#     367             raise LineTooLong("header line")
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/socket.pyc in readline(self, size)
#     474             while True:
#     475                 try:
# --> 476                     data = self._sock.recv(self._rbufsize)
#     477                 except error, e:
#     478                     if e.args[0] == EINTR:
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/ssl.pyc in recv(self, buflen, flags)
#     239                     "non-zero flags not allowed in calls to recv() on %s" %
#     240                     self.__class__)
# --> 241             return self.read(buflen)
#     242         else:
#     243             return self._sock.recv(buflen, flags)
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/ssl.pyc in read(self, len)
#     158
#     159         try:
# --> 160             return self._sslobj.read(len)
#     161         except SSLError, x:
#     162             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:
